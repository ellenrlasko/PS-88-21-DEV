# %%
from schelling import Grid, GroupWeights

# %%
m = Grid(10, .4, GroupWeights(.1, .3, 0.4, .2))
m.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9b0adb47ed96> in <module>
#       1 m = Grid(10, .4, GroupWeights(.1, .3, 0.4, .2))
# ----> 2 m.run()
#
# ~/code/PS-88-21-DEV/lab/lab2/schelling.py in run(self)
#     115         while moved_any is None or moved_any:
#     116             # print(moved_any)
# --> 117             self.plot()
#     118             moved_any = self.move_first()
#     119         self.plot()
#
# ~/code/PS-88-21-DEV/lab/lab2/schelling.py in plot(self)
#      82         legend_without_duplicate_labels(self.ax)
#      83         # self.fig.show()
# ---> 84         plt.show()
#      85
#      86     def move(self, a: Agent):
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     252         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     253     if 'svg' in formats:
# --> 254         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     255     if 'pdf' in formats:
#     256         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1327                 detach = True
#    1328
# -> 1329             self._print_svg(filename, fh, **kwargs)
#    1330
#    1331             # Detach underlying stream from wrapper so that it remains open in
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py in _print_svg(self, filename, fh, dpi, bbox_inches_restore, metadata)
#    1351             bbox_inches_restore=bbox_inches_restore)
#    1352
# -> 1353         self.figure.draw(renderer)
#    1354         renderer.finalize()
#    1355
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/collections.py in draw(self, renderer)
#     929     def draw(self, renderer):
#     930         self.set_sizes(self._sizes, self.figure.dpi)
# --> 931         Collection.draw(self, renderer)
#     932
#     933
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/collections.py in draw(self, renderer)
#     383             else:
#     384                 combined_transform = transform
# --> 385             extents = paths[0].get_extents(combined_transform)
#     386             if (extents.width < self.figure.bbox.width
#     387                     and extents.height < self.figure.bbox.height):
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     597             for curve, code in self.iter_bezier(**kwargs):
#     598                 # places where the derivative is zero can be extrema
# --> 599                 _, dzeros = curve.axis_aligned_extrema()
#     600                 # as can the ends of the curve
#     601                 xys.append(curve([0, *dzeros, 1]))
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/matplotlib/bezier.py in axis_aligned_extrema(self)
#     296         roots = []
#     297         for i, pi in enumerate(dCj.T):
# --> 298             r = np.roots(pi[::-1])
#     299             roots.append(r)
#     300             dims.append(np.full_like(r, i))
#
# <__array_function__ internals> in roots(*args, **kwargs)
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/numpy/lib/polynomial.py in roots(p)
#     241         A = diag(NX.ones((N-2,), p.dtype), -1)
#     242         A[0,:] = -p[1:] / p[0]
# --> 243         roots = eigvals(A)
#     244     else:
#     245         roots = NX.array([])
#
# <__array_function__ internals> in eigvals(*args, **kwargs)
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/numpy/linalg/linalg.py in eigvals(a)
#    1061     _assert_stacked_2d(a)
#    1062     _assert_stacked_square(a)
# -> 1063     _assert_finite(a)
#    1064     t, result_t = _commonType(a)
#    1065
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/numpy/linalg/linalg.py in _assert_finite(*arrays)
#     206 def _assert_finite(*arrays):
#     207     for a in arrays:
# --> 208         if not isfinite(a).all():
#     209             raise LinAlgError("Array must not contain infs or NaNs")
#     210
#
# ~/anaconda3/envs/personal/lib/python3.8/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      54     return umr_any(a, axis, dtype, out, keepdims)
#      55
# ---> 56 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#      57     return umr_all(a, axis, dtype, out, keepdims)
#      58
#
# KeyboardInterrupt:

# %%
g = Grid(5, .5)
g.schelling()

# %% [markdown]
# ## Schelling's Model
# This is an example of how formalizing our understanding of people's beliefs/goals can help explain outcomes. Schelling's model highlights how even minimal preference for in-group proximity can lead to severe segregation between groups. In this section of the problem set, we'll explore a formal model for group proximity preferences and the conclusions we can draw.

# %% [markdown]
# The version of Schelling's model we'll use in this problem set -- which is a bit different than the one from the lectures! -- follows the following process:
# 1) Write a list of houses, denoting a house with a member of Group A or B as an A or B house, and an empty house with an "_". For example, a neighborhood with 2 A houses next to one another, 2 B houses next to one another, and an empty house in between them would be AA_BB
#
# 2) Moving left to right, houses take turns. On a household's turn, they can either (i) stay in place or (ii) move to an empty house.
#
# 3) Repeat until no household wishes to move to an empty house.
#
# We will allow for households to prefer to be (i) closer to other houses with members of their group and (ii) further from houses with members of the other group. This question will explore the implications of different combinations of these motivations.
#
# Just to see how these similations will look, run the following cell to see what happens in a neighborhood where group clusters are next to each other. (We will explain more details about the preferences below.) In the visuals displayed, red dots indicate households of group A, green indicate group B households, and blue dots represent empty houses. The variable <code>basic_neighborhood</code> is set to a string representing the neighborhood.

# %%
from Map import Map, Pref
basic_neighborhood = 'AABB_'
Map.from_string(basic_neighborhood, Pref(0,1), Pref(1,-1)).schelling()

# %% [markdown]
# As we can see, a member of group B swapped with the empty house, at which point no household wanted to switch places.
#
# In the example above, which uses the default priorities, households cared equally about wanting to be close to members of their group as much as they want to avoid members of the outgroup.
#
# To isolate which aspect of these preferences matters more, in the next examples, we will vary the <b>weights</b> that households place on in-group and out-group distance.
#
# We will explore the different implications of these weights by starting with the same integrated community: every household is adjacent by only members of the other group:

# %%
integrated_neighborhood = 'ABABAB___'

# %% [markdown]
# With our baseline community arrangement, we can now let people move in according to Schelling's model. We can start by looking at what happens when households don't care about in-group proximity, only out-group distance.
#
# In particular, this means that they will move if they can find an open house where they will have fewer outgroup neighbors, and if so they will move to a house which minimizes the number of outgroup neighbors.
#
# In the cell below, we do this by setting the variables which the model uses to represent these preferences, <code>ingroup_weight, outgroup_weight </code> to 0 and 1 accordingly.

# %%
ingroup_weight = 0
outgroup_weight = 1

# %% [markdown]
# Now we can run the model!

# %%
neighborhood = Map.from_string(integrated_neighborhood, Pref(0,1), Pref(1,-1))
neighborhood.schelling()
# Out:
# 1.0 3.0
# swapping agents at [0], [8]
# 1.0 2.0
# swapping agents at [2], [7]
# -3.0 -2.0
# swapping agents at [3], [6]
# 1.0 2.0
# swapping agents at [4], [3]
# -3.0 -2.0
# swapping agents at [5], [4]
# -5.0 -2.0
# swapping agents at [1], [2]
# 1.0 2.0
# swapping agents at [3], [0]
# -5.0 -2.0
# swapping agents at [4], [1]
# -5.0 -3.0
# swapping agents at [6], [5]
# -3.0 -2.0
# swapping agents at [2], [6]
# 1.0 2.0
# swapping agents at [7], [3]
# -5.0 -2.0
# swapping agents at [1], [2]
# -3.0 -2.0
# swapping agents at [5], [1]
# -6.0 -2.0
# swapping agents at [6], [7]
# 1.0 2.0
# swapping agents at [8], [5]
# 1.0 2.0
# swapping agents at [0], [4]
# -3.0 -2.0
# swapping agents at [1], [6]
# -5.0 -3.0
# swapping agents at [2], [1]
# -3.0 -2.0
# swapping agents at [7], [2]
# 1.0 2.0
# swapping agents at [3], [8]
# -5.0 -2.0
# swapping agents at [6], [3]
# 1.0 4.0
# swapping agents at [4], [7]
# 2.0 3.0
# swapping agents at [5], [6]
# -6.0 -3.0
# swapping agents at [1], [5]
# -5.0 -3.0
# swapping agents at [2], [4]
# 1.0 3.0
# swapping agents at [6], [0]
# -4.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [7], [1]
# -4.0 -2.0
# swapping agents at [4], [7]
# 1.0 3.0
# swapping agents at [8], [2]
# -4.0 -3.0
# swapping agents at [5], [4]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [7]
# -4.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [7], [1]
# -4.0 -2.0
# swapping agents at [4], [7]
# 1.0 3.0
# swapping agents at [8], [2]
# -4.0 -3.0
# swapping agents at [5], [3]
# -5.0 -3.0
# swapping agents at [6], [4]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [1]
# -3.0 -2.0
# swapping agents at [3], [2]
# -4.0 -3.0
# swapping agents at [4], [3]
# -5.0 -3.0
# swapping agents at [5], [7]
# 1.0 2.0
# swapping agents at [1], [5]
# -3.0 -2.0
# swapping agents at [2], [4]
# -3.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [8], [1]
# 1.0 2.0
# swapping agents at [5], [2]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [7]
# -4.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [7], [1]
# -4.0 -2.0
# swapping agents at [4], [7]
# 1.0 3.0
# swapping agents at [8], [2]
# -4.0 -3.0
# swapping agents at [5], [4]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [1]
# -3.0 -2.0
# swapping agents at [3], [2]
# -4.0 -3.0
# swapping agents at [4], [3]
# -5.0 -3.0
# swapping agents at [5], [7]
# 1.0 2.0
# swapping agents at [1], [5]
# -3.0 -2.0
# swapping agents at [2], [4]
# -3.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [8], [1]
# 1.0 2.0
# swapping agents at [5], [2]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [7]
# -4.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [7], [1]
# -4.0 -2.0
# swapping agents at [4], [7]
# 1.0 3.0
# swapping agents at [8], [2]
# -4.0 -3.0
# swapping agents at [5], [4]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [1]
# -3.0 -2.0
# swapping agents at [3], [2]
# -4.0 -3.0
# swapping agents at [4], [3]
# -5.0 -3.0
# swapping agents at [5], [7]
# 1.0 2.0
# swapping agents at [1], [5]
# -3.0 -2.0
# swapping agents at [2], [4]
# -3.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [8], [1]
# 1.0 2.0
# swapping agents at [5], [2]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [7]
# -4.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [7], [1]
# -4.0 -2.0
# swapping agents at [4], [7]
# 1.0 3.0
# swapping agents at [8], [2]
# -4.0 -3.0
# swapping agents at [5], [4]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [1]
# -3.0 -2.0
# swapping agents at [3], [2]
# -4.0 -3.0
# swapping agents at [4], [3]
# -5.0 -3.0
# swapping agents at [5], [7]
# 1.0 2.0
# swapping agents at [1], [5]
# -3.0 -2.0
# swapping agents at [2], [4]
# -3.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [8], [1]
# 1.0 2.0
# swapping agents at [5], [2]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [7]
# -4.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [7], [1]
# -4.0 -2.0
# swapping agents at [4], [7]
# 1.0 3.0
# swapping agents at [8], [2]
# -4.0 -3.0
# swapping agents at [5], [4]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [1]
# -3.0 -2.0
# swapping agents at [3], [2]
# -4.0 -3.0
# swapping agents at [4], [3]
# -5.0 -3.0
# swapping agents at [5], [7]
# 1.0 2.0
# swapping agents at [1], [5]
# -3.0 -2.0
# swapping agents at [2], [4]
# -3.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [8], [1]
# 1.0 2.0
# swapping agents at [5], [2]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [7]
# -4.0 -2.0
# swapping agents at [3], [6]
# 1.0 3.0
# swapping agents at [7], [1]
# -4.0 -2.0
# swapping agents at [4], [7]
# 1.0 3.0
# swapping agents at [8], [2]
# -4.0 -3.0
# swapping agents at [5], [4]
# -5.0 -2.0
# swapping agents at [6], [3]
# -8.0 -4.0
# swapping agents at [7], [5]
# 2.0 3.0
# swapping agents at [1], [8]
# 1.0 2.0
# swapping agents at [2], [1]
# -3.0 -2.0
# swapping agents at [3], [2]
# -4.0 -3.0
# swapping agents at [4], [3]
# -5.0 -3.0
# swapping agents at [5], [7]
# 1.0 2.0
# swapping agents at [1], [5]
# -3.0 -2.0
# swapping agents at [2], [4]

# %% [markdown]
# How does only prioritizing avoiding the outgroup affect the eventual housing arrangement?
# <font color="blue"> <b> In the cell below, describe how segregated the population is at the end, and why the final arrangement is stable. (2 pts) </b></font>

# %% [markdown]
# EXPLANATION HERE

# %% [markdown]
# What happens when we *only* care about in-group proximity. This means that they will move if they can find a house where they will have more in-group neighbors, and will move to the house which gives them the most in-group neighbors.

# %%
ingroup_weight = 1 
outgroup_weight = 0
neighborhood = Map.from_string(integrated_neighborhood)
neighborhood.schelling(ingroup_weight, outgroup_weight)

# %% [markdown]
# How does this differ from the out-group avoidance result?
# <font color="blue"> <b> In the cell below,  describe the housing arrangement and explain why we would expect this as a result of the priorities. Make sure to compare it to the previous preference structure (2 pts). </b></font>

# %%
NEW EXPLANATION HERE

# %% [markdown]
# What if we care about proximity to the in-group *and* the out-group? The following cell sets both weights to 1, so households place equal weight on their closeness to other members of their group and their distance away from members of the other group. (It's not important for our purposes, but the way this is done formally is by computing a "utility" associated with each potential house, with higher utility given to houses with more in-group neighbors and fewer out-group neighbors.)

# %% [markdown]
# ingroup_weight = 1
# outgroup_weight = 1
# neighborhood = Map.from_string(integrated_neighborhood)
# neighborhood.schelling(ingroup_weight, outgroup_weight)

# %% [markdown]
# How does this result differ from when we cared about only one kind of group proximity? Does it more closely match one of singular preference outcomes?
# <font color="blue"> <b> In the cell below, compare the outcome when the agents care about both avoiding the other group and trying to live near the ingroup to the cases where they only cared about one or the other (1 pt). </b></font>

# %% [markdown]
# EXPLANATION HERE

# %% [markdown]
# As a final exercise with this model, choose your own values for the initial community structure and group proximity preferences.
# <font color="blue"> <b> In the cell below, set the variable <code>your_neighborhood</code> to a string representing a community of your own design and set the group proximity preference variables <code>ingroup_weight, outgroup_weight</code> (1 pt). </b></font>

# %%
your_neighborhood = ...
ingroup_weight = ...
outgroup_weight = ...

neighborhood = Map.from_string(your_neighborhood)
neighborhood.schelling(ingroup_weight, outgroup_weight)

# %% [markdown]
# <font color="blue"> <b> Why did you choose the combination of initial conditions and weights that you did? What do you think we can learn about housing dynamics from this version of the model (1 pt)? </b>

# %%
SUMMARY HERE

# %% [markdown]
# We can also generolize this model to

# %%
# %matplotlib inline
from utils import Grid
from IPython.display import HTML
from matplotlib import animation, rc
rc('animation', html='html5')
g = Grid(5, .5)
g.schelling()

# %%
display(HTML(g.anim.to_html5_video()))
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
